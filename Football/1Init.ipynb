# %%
# !pip install selenium
# !pip install webdriver-manager
# !pip install BeautifulSoup4
# !pip install --upgrade pandas
# !pip install undetected-chromedriver

# %%
import matplotlib.pyplot as plt
import urllib.request, json 
import seaborn as sns
import pandas as pd
import numpy as np
import unicodedata
import webbrowser
import requests
# import datetime
import warnings
import math
import csv
import os
import re


pd.set_option("display.max.columns", None)
pd.set_option("display.max.rows", None)
warnings.filterwarnings("ignore", message="A NumPy version*")

from webdriver_manager.chrome import ChromeDriverManager
from IPython.display import display, HTML
from datetime import datetime, date, timedelta
from unidecode import unidecode
from selenium import webdriver
from bs4 import BeautifulSoup
from itertools import chain
from tqdm import tqdm

import datetime


##################################################################### Functions
def get_page(special_match):
    # Ensure the URL has https://
    if not special_match.startswith("http"):
        special_match = "https://" + special_match
        
    driver.get(special_match)
    
    try:
        # We use the new 'By' syntax here
        element = driver.find_element(By.CLASS_NAME, 'banner-actions-container')
        element.click()
        print("Cookie banner cleared.")
    except Exception:
        # This triggers if the banner isn't there (which is fine)
        pass
# Out:
# C:\Users\legrasv\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
