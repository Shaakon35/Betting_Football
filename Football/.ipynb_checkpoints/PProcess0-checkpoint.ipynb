# %%
# !pip install selenium
# !pip install webdriver-manager
# !pip install BeautifulSoup4
# !pip install --upgrade pandas
# !pip install undetected-chromedriver
# Out:
# Collecting undetected-chromedriver
#   Downloading undetected-chromedriver-3.5.5.tar.gz (65 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: selenium>=4.9.0 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from undetected-chromedriver) (4.40.0)
# Requirement already satisfied: requests in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from undetected-chromedriver) (2.32.3)
# Requirement already satisfied: websockets in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from undetected-chromedriver) (15.0.1)
# Requirement already satisfied: certifi>=2026.1.4 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (2026.1.4)
# Requirement already satisfied: trio<1.0,>=0.31.0 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (0.32.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (0.12.2)
# Requirement already satisfied: trio-typing>=0.10.0 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (0.10.0)
# Requirement already satisfied: types-certifi>=2021.10.8.3 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (2021.10.8.3)
# Requirement already satisfied: types-urllib3>=1.26.25.14 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (1.26.25.14)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (4.15.0)
# Requirement already satisfied: urllib3<3.0,>=2.6.3 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium>=4.9.0->undetected-chromedriver) (2.6.3)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver) (24.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver) (2.4.0)
# Requirement already satisfied: idna in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver) (3.7)
# Requirement already satisfied: outcome in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from trio-websocket<1.0,>=0.12.2->selenium>=4.9.0->undetected-chromedriver) (1.3.2)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium>=4.9.0->undetected-chromedriver) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver) (2.21)
# Requirement already satisfied: mypy-extensions>=0.4.2 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from trio-typing>=0.10.0->selenium>=4.9.0->undetected-chromedriver) (1.0.0)
# Requirement already satisfied: async-generator in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from trio-typing>=0.10.0->selenium>=4.9.0->undetected-chromedriver) (1.10)
# Requirement already satisfied: packaging in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from trio-typing>=0.10.0->selenium>=4.9.0->undetected-chromedriver) (24.2)
# Requirement already satisfied: importlib-metadata in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from trio-typing>=0.10.0->selenium>=4.9.0->undetected-chromedriver) (8.5.0)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium>=4.9.0->undetected-chromedriver) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from importlib-metadata->trio-typing>=0.10.0->selenium>=4.9.0->undetected-chromedriver) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\legrasv\appdata\local\anaconda3\lib\site-packages (from requests->undetected-chromedriver) (3.3.2)
# Building wheels for collected packages: undetected-chromedriver
#   Building wheel for undetected-chromedriver (setup.py): started
#   Building wheel for undetected-chromedriver (setup.py): finished with status 'done'
#   Created wheel for undetected-chromedriver: filename=undetected_chromedriver-3.5.5-py3-none-any.whl size=47131 sha256=bf8bed188f4f899d3ed8cb2c3ac4f9465abb5099ac025209a0e5e987958fc905
#   Stored in directory: c:\users\legrasv\appdata\local\pip\cache\wheels\7a\5f\c1\06f68421cc7172ef51504631252870bcb3a2fdf3b6a025f362
# Successfully built undetected-chromedriver
# Installing collected packages: undetected-chromedriver
# Successfully installed undetected-chromedriver-3.5.5
#   DEPRECATION: Building 'undetected-chromedriver' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'undetected-chromedriver'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
import matplotlib.pyplot as plt
import urllib.request, json 
import seaborn as sns
import pandas as pd
import numpy as np
import unicodedata
import webbrowser
import requests
# import datetime
import warnings
import math
import csv
import os
import re


pd.set_option("display.max.columns", None)
pd.set_option("display.max.rows", None)
warnings.filterwarnings("ignore", message="A NumPy version*")

from webdriver_manager.chrome import ChromeDriverManager
from IPython.display import display, HTML
from datetime import datetime, date, timedelta
from unidecode import unidecode
from selenium import webdriver
from bs4 import BeautifulSoup
from itertools import chain
from tqdm import tqdm

import datetime


##################################################################### Functions
def get_page(special_match):
    # Ensure the URL has https://
    if not special_match.startswith("http"):
        special_match = "https://" + special_match
        
    driver.get(special_match)
    
    try:
        # We use the new 'By' syntax here
        element = driver.find_element(By.CLASS_NAME, 'banner-actions-container')
        element.click()
        print("Cookie banner cleared.")
    except Exception:
        # This triggers if the banner isn't there (which is fine)
        pass
# Out:
# C:\Users\legrasv\AppData\Local\Temp\ipykernel_1964\2159682904.py:22: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython.display
#   from IPython.core.display import display, HTML
