# %%
### Germany
DictTeam = {'VfB Stuttgart': 'Stuttgart',
 'FC Augsburg': 'Augsbourg',
 'Karlsruher SC': 'Karlsruhe',
 'SC Paderborn 07': 'Paderborn',
 '1. FC Heidenheim': 'Heidenheim',
 'SSV Jahn Regensburg': 'Jahn Regensburg',
 'Holstein Kiel': 'Holstein Kiel',
 'FC St. Pauli': 'St. Pauli',
 'VfL Bochum': 'Bochum',
 'Bayern Munich': 'Bayern Munich',
 'Arminia Bielefeld': 'Arminia Bielefeld',
 'RB Leipzig': 'RB Leipzig',
 'Hansa Rostock': 'Hansa Rostock',
 'Hertha Berlin': 'Hertha BSC',
 'TSG Hoffenheim': 'Hoffenheim',
 'SV Darmstadt 98': 'Darmstadt',
 'Bayer Leverkusen': 'Bayer Leverkusen',
 'VfL Wolfsburg': 'Wolfsbourg',
 'Fortuna Düsseldorf': 'Dusseldorf',
 '1. FC Magdeburg': 'Magdeburg',
 'Eintracht Frankfurt': 'Eintracht Francfort',
 '1. FC Union Berlin': 'Union Berlin',
 'Mayence': 'Mainz',
 'Schalke 04': 'Schalke 04',
 'Kaiserslautern': 'Kaiserslautern',
 'SC Freiburg': 'Fribourg',
 'TSV Eintracht Braunschweig': 'Braunschweig',
 'Hannover 96': 'Hanovre',
 'Borussia Dortmund': 'Dortmund',
 'Werder Bremen': 'Werder Breme',
     
     
 'FC Cologne': 'Cologne',
 'SV Sandhausen': 'Sandhausen',
 'Nuremberg': 'Nurnberg',
 'SC Amiens': 'Amiens',
 'AJ Auxerre': 'Auxerre',
 'Clermont Foot': 'Clermont',
 'Dijon FCO': 'Dijon',
 'FC Annecy': 'Annecy',
 'Grenoble Foot': 'Grenoble',
 'Stade Laval': 'Laval',
 'Le Havre AC': 'Le Havre',
 'AS Monaco': 'Monaco',
 'Paris Saint-Germain ': 'Paris SG',
 'Quevilly-Rouen': 'US Quevilly',
 'Stade de Reims': 'Reims',
 'Stade Rennais': 'Rennes',
 'Rodez Aveyron Football': 'Rodez Aveyron',
     
     
 'Albacete Balompie': 'Albacete',
 'Almeria': 'Almería',
 'Athletic Bilbao': 'Athletic Club',
 'Betis Seville': 'Real Betis',
 'Burgos CF': 'Burgos',
 'FC Carthagene': 'FC Cartagena',
 'Cadiz CF': 'Cádiz',
 'Deportivo Alaves': 'Alavés',
 'Espanyol Barcelona': 'Espanyol',
 'FC Barcelone': 'Barcelona',
 'Gerone': 'Girona',
 'Grenade': 'Granada',
 'Leganes': 'Leganés',
 'Majorque': 'Mallorca',
 'Malaga CF': 'Málaga',
 'Mirandes': 'Mirandés',
 'RC Celta Vigo': 'Celta Vigo',
 'Seville': 'Sevilla',
 'Sporting Gijon': 'Sporting Gijón',
 'Tenerife CD': 'Tenerife',
 'Valencia': 'Valence',
 'Real Valladolid': 'Valladolid',
 'Villarreal CF B': 'Villarreal B',
     
     
 'AC Monza': 'Monza',
 'AS Rome': 'AS Roma',
 'Atalanta Bergame': 'Atalanta',
 'Come': 'Como',
 'FC Sudtirol Bolzano': 'Suditrol',
 'Frosinone Calcio': 'Frosinone',
 'Hellas Verone': 'Hellas Verona',
 'Internazionale': 'Inter Milan',
 'Juventus Turin': 'Juventus',
 'Lazio Rome': 'Lazio',
 'Milan AC': 'AC Milan',
 'Modena FC': 'Modena',
 'Naples': 'Napoli',
 'Parme': 'Parma',
 'Pise': 'Pisa',
 'Reggina 1914': 'Reggina',
 'SSC Bari': 'Bari',
 'Sassuolo Calcio': 'Sassuolo',
 'Spezia Calcio': 'Spezia',
 'Ternana Calcio': 'Ternana',
 'US Lecce': 'Lecce',
 'US Salernitana': 'Salernitana',
     
     
 'Birmingham City': 'Birmingham C.',
 'AFC Bournemouth': 'Bournemouth',
 'Blackburn Rovers': 'Blackburn',
 'Brighton & Hove Albion': 'Brighton',
 'Chelsea FC': 'Chelsea',
 'Fulham FC': 'Fulham',
 'Leicester City': 'Leicester',
 'Middlesbrough FC': 'Middlesbrough',
 'Millwall FC': 'Millwall',
 'Huddersfield Town': 'Huddersfield',
 'Newcastle United': 'Newcastle',
 'Queens Park Rangers': 'QPR',
 'Reading FC': 'Reading',
 'Swansea City': 'Swansea',
 'Tottenham Hotspur': 'Tottenham',
 'West Bromwich Albion': 'West Bromwich',
 'West Ham United': 'West Ham',
 'Sunderland AFC': 'Sunderland',
     
     
 'SK Austria Klagenfurt': 'Austria Klagenfurt',
 'Wolfsberger AC': 'Wolfsberger',
 'Rapid Vienna': 'Rapid Vienne',
 'RB Salzbourg': 'FC Salzburg',
 'SC Rheindorf Altach': 'SCR Altach',
 'SK Sturm Graz': 'Sturm Graz',
 'WSG Swarovski Tirol': 'WSG Swarovski Tirol',
     
     "Hambourg": "Hamburger SV",
 'Austria Lustenau': 'A. Lustenau',
 'SV Josko Ried': 'SV Ried',
 'TSV Hartberg': 'TSV Hartberg',
 'Aalborg BK': 'AaB',
 'AGF Aarhus': 'Aarhus GF',
 'Aberdeen FC': 'Aberdeen',
 'Brondby': 'Brøndby',
 'Randers FC': 'Randers',
 'Kilmarnock FC': 'Kilmarnock',
 'Lyngby BK': 'Lyngby',
 'Motherwell FC': 'Motherwell',
 'Silkeborg IF': 'Silkeborg'

}
    
    
    
    
#     "Borussia Monchengladbach": "Borussia M'Gladbach",
#     "M'gladbach": "Borussia Monchengladbach",
#     "Hambourg": "Hamburger SV",
#     "Hamburg SV": "Hambourg",
#     "HamburgerSV": "Hambourg",
#     "SpVgg Greuther Furth": "Greuther Furth",
#     "SpVgg Greuther Furth": "Greutehr Furth",

#France

    
#Spain
    
#Italy
#     "Bologne FC": "Bologna",
#     "Bologne": "Bologna",
#     "Palermo FC": "Palermo",
#     "Palerme FC": "Palermo FC",
#     "Perouse": "Perugia",
#     "Perouse Calcio Spa": "Perugia",
    
#England
#     "Wolverhampton Wanderers": "Wolverhampton",
#     "Wanderers": "Wolverhampton",
    
#Austria
#     "Austria Vienne": "FK Austria Vienne",
#     "Austria Vienna": "FK Austria Vienne",
#     "Autriche Wien": "FK Austria Vienne",
#     "LASK Linz": "LASK", 
#     "Linz": "LASK Linz",
    

#Denmark/Scotland
#     "Copenhague": "FC Copenhague",
#     "FC Copenhagen": "FC Copenhague",
#     "FCCopenhague": "FC Copenhague",
#     "Ross County": "Ross County FC",
#     "FC\tRoss County": "Ross County FC",

merged_dict={}
for key, value in DictTeam.items():
    if len(key) < len(value):
        merged_dict[value] = key
    else:
        merged_dict[key] = value
merged_dict
# Out:
# {'VfB Stuttgart': 'Stuttgart',
#  'FC Augsburg': 'Augsbourg',
#  'Karlsruher SC': 'Karlsruhe',
#  'SC Paderborn 07': 'Paderborn',
#  '1. FC Heidenheim': 'Heidenheim',
#  'SSV Jahn Regensburg': 'Jahn Regensburg',
#  'Holstein Kiel': 'Holstein Kiel',
#  'FC St. Pauli': 'St. Pauli',
#  'VfL Bochum': 'Bochum',
#  'Bayern Munich': 'Bayern Munich',
#  'Arminia Bielefeld': 'Arminia Bielefeld',
#  'RB Leipzig': 'RB Leipzig',
#  'Hansa Rostock': 'Hansa Rostock',
#  'Hertha Berlin': 'Hertha BSC',
#  'TSG Hoffenheim': 'Hoffenheim',
#  'SV Darmstadt 98': 'Darmstadt',
#  'Bayer Leverkusen': 'Bayer Leverkusen',
#  'VfL Wolfsburg': 'Wolfsbourg',
#  'Fortuna Düsseldorf': 'Dusseldorf',
#  '1. FC Magdeburg': 'Magdeburg',
#  'Eintracht Frankfurt': 'Eintracht Francfort',
#  '1. FC Union Berlin': 'Union Berlin',
#  'Mayence': 'Mainz',
#  'Schalke 04': 'Schalke 04',
#  'Kaiserslautern': 'Kaiserslautern',
#  'SC Freiburg': 'Fribourg',
#  'TSV Eintracht Braunschweig': 'Braunschweig',
#  'Hannover 96': 'Hanovre',
#  'Borussia Dortmund': 'Dortmund',
#  'Werder Bremen': 'Werder Breme',
#  'FC Cologne': 'Cologne',
#  'SV Sandhausen': 'Sandhausen',
#  'Nuremberg': 'Nurnberg',
#  'SC Amiens': 'Amiens',
#  'AJ Auxerre': 'Auxerre',
#  'Clermont Foot': 'Clermont',
#  'Dijon FCO': 'Dijon',
#  'FC Annecy': 'Annecy',
#  'Grenoble Foot': 'Grenoble',
#  'Stade Laval': 'Laval',
#  'Le Havre AC': 'Le Havre',
#  'AS Monaco': 'Monaco',
#  'Paris Saint-Germain ': 'Paris SG',
#  'Quevilly-Rouen': 'US Quevilly',
#  'Stade de Reims': 'Reims',
#  'Stade Rennais': 'Rennes',
#  'Rodez Aveyron Football': 'Rodez Aveyron',
#  'Albacete Balompie': 'Albacete',
#  'Almeria': 'Almería',
#  'Athletic Bilbao': 'Athletic Club',
#  'Betis Seville': 'Real Betis',
#  'Burgos CF': 'Burgos',
#  'FC Carthagene': 'FC Cartagena',
#  'Cadiz CF': 'Cádiz',
#  'Deportivo Alaves': 'Alavés',
#  'Espanyol Barcelona': 'Espanyol',
#  'FC Barcelone': 'Barcelona',
#  'Gerone': 'Girona',
#  'Grenade': 'Granada',
#  'Leganes': 'Leganés',
#  'Majorque': 'Mallorca',
#  'Malaga CF': 'Málaga',
#  'Mirandes': 'Mirandés',
#  'RC Celta Vigo': 'Celta Vigo',
#  'Seville': 'Sevilla',
#  'Sporting Gijon': 'Sporting Gijón',
#  'Tenerife CD': 'Tenerife',
#  'Valencia': 'Valence',
#  'Real Valladolid': 'Valladolid',
#  'Villarreal CF B': 'Villarreal B',
#  'AC Monza': 'Monza',
#  'AS Rome': 'AS Roma',
#  'Atalanta Bergame': 'Atalanta',
#  'Come': 'Como',
#  'FC Sudtirol Bolzano': 'Suditrol',
#  'Frosinone Calcio': 'Frosinone',
#  'Hellas Verone': 'Hellas Verona',
#  'Internazionale': 'Inter Milan',
#  'Juventus Turin': 'Juventus',
#  'Lazio Rome': 'Lazio',
#  'Milan AC': 'AC Milan',
#  'Modena FC': 'Modena',
#  'Naples': 'Napoli',
#  'Parme': 'Parma',
#  'Pise': 'Pisa',
#  'Reggina 1914': 'Reggina',
#  'SSC Bari': 'Bari',
#  'Sassuolo Calcio': 'Sassuolo',
#  'Spezia Calcio': 'Spezia',
#  'Ternana Calcio': 'Ternana',
#  'US Lecce': 'Lecce',
#  'US Salernitana': 'Salernitana',
#  'Birmingham City': 'Birmingham C.',
#  'AFC Bournemouth': 'Bournemouth',
#  'Blackburn Rovers': 'Blackburn',
#  'Brighton & Hove Albion': 'Brighton',
#  'Chelsea FC': 'Chelsea',
#  'Fulham FC': 'Fulham',
#  'Leicester City': 'Leicester',
#  'Middlesbrough FC': 'Middlesbrough',
#  'Millwall FC': 'Millwall',
#  'Huddersfield Town': 'Huddersfield',
#  'Newcastle United': 'Newcastle',
#  'Queens Park Rangers': 'QPR',
#  'Reading FC': 'Reading',
#  'Swansea City': 'Swansea',
#  'Tottenham Hotspur': 'Tottenham',
#  'West Bromwich Albion': 'West Bromwich',
#  'West Ham United': 'West Ham',
#  'Sunderland AFC': 'Sunderland',
#  'SK Austria Klagenfurt': 'Austria Klagenfurt',
#  'Wolfsberger AC': 'Wolfsberger',
#  'Rapid Vienna': 'Rapid Vienne',
#  'RB Salzbourg': 'FC Salzburg',
#  'SC Rheindorf Altach': 'SCR Altach',
#  'SK Sturm Graz': 'Sturm Graz',
#  'WSG Swarovski Tirol': 'WSG Swarovski Tirol',
#  'Austria Lustenau': 'A. Lustenau',
#  'SV Josko Ried': 'SV Ried',
#  'TSV Hartberg': 'TSV Hartberg',
#  'Aalborg BK': 'AaB',
#  'AGF Aarhus': 'Aarhus GF',
#  'Aberdeen FC': 'Aberdeen',
#  'Brondby': 'Brøndby',
#  'Randers FC': 'Randers',
#  'Kilmarnock FC': 'Kilmarnock',
#  'Lyngby BK': 'Lyngby',
#  'Motherwell FC': 'Motherwell',
#  'Silkeborg IF': 'Silkeborg'}

# %%
# ### Germany
# replace_dict1 = {
#     'VfB Stuttgart': 'Stuttgart',
#     'FC Augsburg': 'Augsbourg',
#     'Karlsruher SC': 'Karlsruher SC', 'Karlsruhe': 'Karlsruher SC',
#     'SC Paderborn 07': 'Paderborn',
#     '1. FC Heidenheim': 'Heidenheim',
#     'SSV Jahn Regensburg': 'Jahn Regensburg',
#     'Holstein Kiel': 'Holstein Kiel',
#     'FC St. Pauli': 'St. Pauli',
#     'VfL Bochum': 'Bochum',
#     'Bayern Munich': 'Bayern Munich',
#     'Arminia Bielefeld': 'Arminia Bielefeld',
#     'RB Leipzig': 'RB Leipzig',
#     'Hambourg': 'Hamburger SV',
#     'Hansa Rostock': 'Hansa Rostock',
#     'Hertha Berlin': 'Hertha BSC',
#     'TSG Hoffenheim': 'Hoffenheim',
#     'SV Darmstadt 98': 'SV Darmstadt 98', 
#     'Darmstadt': 'SV Darmstadt 98',
#     'Bayer Leverkusen': 'Bayer Leverkusen',
#     'VfL Wolfsburg': 'Wolfsbourg',
#     'Fortuna Düsseldorf': 'Fortuna Düsseldorf', 
#     'Dusseldorf': 'Fortuna Düsseldorf',
#     'Borussia Monchengladbach': 'Borussia M'Gladbach',
#     'M'gladbach': 'Borussia Monchengladbach',
#     '1. FC Magdeburg': 'Magdeburg',
#     'Eintracht Frankfurt': 'Eintracht Francfort',
#     '1. FC Union Berlin': 'Union Berlin',
#     'Hamburg SV': 'Hambourg',
#     'HamburgerSV': 'Hambourg',
#     'Mainz': 'Mayence',
#     'Schalke 04': 'Schalke 04',
#     'Kaiserslautern': 'Kaiserslautern',
#     'SC Freiburg': 'Fribourg',
#     'SpVgg Greuther Furth': 'Greuther Furth',
#     'SpVgg Greuther Furth': 'Greutehr Furth',
#     'TSV Eintracht Braunschweig': 'Braunschweig',
#     'Hannover 96': 'Hanovre',
#     'Borussia Dortmund': 'Dortmund',
#     'Werder Bremen': 'Werder Breme',
#     'FC Cologne': 'Cologne',
#     'SV Sandhausen': 'Sandhausen',
#     'Nurnberg': 'Nuremberg'
#     }

# #France
# replace_dict2 = {
#     'Amiens': 'SC Amiens',
#     'Auxerre': 'AJ Auxerre',
#     'Clermont': 'Clermont Foot',
#     'Dijon': 'Dijon FCO',
#     'FC Annecy': 'Annecy',
#     'Grenoble Foot': 'Grenoble',
#     'Laval': 'Stade Laval',
#     'Le Havre': 'Le Havre AC',
#     'Monaco': 'AS Monaco',
#     'Paris SG': 'Paris Saint-Germain ',
#     'Quevilly-Rouen': 'US Quevilly',
#     'Reims': 'Stade de Reims',
#     'Rennes': 'Stade Rennais',
#     'Rodez Aveyron Football': 'Rodez Aveyron'
#     }

# #Spain
# replace_dict3 = {
#     'Albacete Balompie': 'Albacete',
#     'Almeria': 'Almería',
#     'Athletic Bilbao': 'Athletic Club',
#     'Betis Seville': 'Real Betis',
#     'Burgos CF': 'Burgos',
#     'FC Carthagene': 'FC Cartagena',
#     'Cadiz CF': 'Cádiz',
#     'Deportivo Alaves': 'Alavés',
#     'Espanyol Barcelona': 'Espanyol',
#     'FC Barcelone': 'Barcelona',
#     'Gerone': 'Girona',
#     'Grenade': 'Granada',
#     'Leganes': 'Leganés',
#     'Majorque': 'Mallorca',
#     'Malaga CF': 'Málaga',
#     'Mirandes': 'Mirandés',
#     'RC Celta Vigo': 'Celta Vigo',
#     'Seville': 'Sevilla',
#     'Sporting Gijon': 'Sporting Gijón',
#     'Tenerife CD': 'Tenerife',
#     'Valence': 'Valencia',
#     'Valladolid': 'Real Valladolid',
#     'Villarreal CF B': 'Villarreal B'
#     }

# #Italy
# replace_dict4 = {
#     'AC Monza': 'Monza',
#     'AS Rome': 'AS Roma',
#     'Atalanta Bergame': 'Atalanta',
#     'Bologne FC': 'Bologna',
#     'Bologne': 'Bologna',
#     'Come': 'Como',
#     'FC Sudtirol Bolzano': 'Suditrol',
#     'Frosinone Calcio': 'Frosinone',
#     'Hellas Verone': 'Hellas Verona',
#     'Inter Milan': 'Internazionale',
#     'Juventus Turin': 'Juventus',
#     'Lazio Rome': 'Lazio',
#     'Milan AC': 'AC Milan',
#     'Modena FC': 'Modena',
#     'Naples': 'Napoli',
#     'Palermo FC': 'Palermo',
#     'Palerme FC': 'Palermo FC',
#     'Parme': 'Parma',
#     'Perouse': 'Perugia',
#     'Pérouse Calcio Spa': 'Perugia',
#     'Pise': 'Pisa',
#     'Reggina 1914': 'Reggina',
#     'SSC Bari': 'Bari',
#     'Sassuolo Calcio': 'Sassuolo',
#     'Spezia Calcio': 'Spezia',
#     'Ternana Calcio': 'Ternana',
#     'US Lecce': 'Lecce',
#     'US Salernitana': 'Salernitana'
#     }

# #England
# replace_dict5 = {
#     'Birmingham C.': 'Birmingham City',
#     'Bournemouth': 'AFC Bournemouth',
#     'Blackburn': 'Blackburn Rovers',
#     'Brighton': 'Brighton & Hove Albion',
#     'Chelsea FC': 'Chelsea',
#     'Fulham FC': 'Fulham',
#     'Leicester': 'Leicester City',
#     'Middlesbrough FC': 'Middlesbrough',
#     'Millwall FC': 'Millwall',
#     'Huddersfield': 'Huddersfield Town',
#     'Newcastle': 'Newcastle United',
#     'QPR': 'Queens Park Rangers',
#     'Reading FC': 'Reading',
#     'Swansea': 'Swansea City',
#     'Tottenham': 'Tottenham Hotspur',
#     'West Bromwich': 'West Bromwich Albion',
#     'Tottenham': 'Tottenham Hotspur',
#     'West Bromwich': 'West Bromwich Albion',
#     'Wolverhampton Wanderers': 'Wolverhampton',
#     'Wanderers': 'Wolverhampton',
#     'West Ham United': 'West Ham',
#     'Sunderland': 'Sunderland AFC',
#     }

# #Austria
# replace_dict6 = {
#     'SK Austria Klagenfurt':  'Austria Klagenfurt',
#     'Wolfsberger': 'Wolfsberger AC',
#     'Rapid Vienna': 'Rapid Vienne',
#     'FC Salzburg': 'RB Salzbourg',
#     'SC Rheindorf Altach': 'SCR Altach',
#     'SK Sturm Graz': 'Sturm Graz',
#     'WSG Swarovski Tirol': 'WSG Swarovski Tirol',
#     'Austria Vienne': 'FK Austria Vienne',
#     'Austria Vienna': 'FK Austria Vienne',
#     'Autriche Wien': 'FK Austria Vienne',
#     'A. Lustenau': 'Austria Lustenau',
#     'SV Josko Ried': 'SV Ried',
#     'TSV Hartberg': 'TSV Hartberg',
#     'LASK Linz': 'LASK', 'Linz': 'LASK Linz'
#     }

# #Denmark/Scotland
# replace_dict7 = {
#     'Aalborg BK': 'AaB',
#     'Aarhus GF': 'AGF Aarhus',
#     'Aberdeen FC': 'Aberdeen',
#     'Brondby': 'Brøndby',
#     'Randers': 'Randers FC',
#     'Copenhague': 'FC Copenhague',
#     'FC Copenhagen': 'FC Copenhague',
#     'FCCopenhague': 'FC Copenhague',
#     'Kilmarnock FC': 'Kilmarnock',
#     'Lyngby BK': 'Lyngby',
#     'Motherwell FC': 'Motherwell',
#     'Ross County': 'Ross County FC',
#     'FC\tRoss County': 'Ross County FC',
#     'Silkeborg': 'Silkeborg IF',
# }

# merged_dict0 = {}
# merged_dict0.update(replace_dict1)
# merged_dict0.update(replace_dict2)
# merged_dict0.update(replace_dict3)
# merged_dict0.update(replace_dict4)
# merged_dict0.update(replace_dict5)
# merged_dict0.update(replace_dict6)
# merged_dict0.update(replace_dict7)

# merged_dict = {}

# for key, value in merged_dict0.items():
#     if len(key) < len(value):
#         merged_dict[value] = key
#     else:
#         merged_dict[key] = value
