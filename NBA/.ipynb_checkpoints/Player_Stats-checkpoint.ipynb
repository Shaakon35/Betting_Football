# %% [markdown]
# # Betting on NBA

# %%
#TO IMPROVE
# min à 0 lorsque joue pas
# Prendre en compte blessure top7 joueurs - flag nb match avec sans gros joueur
# Poids sur les derniers matchs
# https://www.espn.com/nba/injuries

# Lonnie Walker IV ?

# Prendre l'equipe en face en compte, nombre de points de rebonds, etc.
# 3 points tir 
# flag if injuries last match

# Ne pas prendre en compte si un joueur a joué moins
#Moyenne au llieu du minimum sera plus significatif

#get notif fro new odds unibet Winamax, Betclic
#Problem two Jackson counted twice because they played in the same match Grinzzlies vs LAC

# %%
#pip install selenium
#pip install webdriver-manager
#pip install BeautifulSoup4
import pandas as pd
import numpy as np
import re
import requests
import webbrowser
import seaborn as sns
import urllib.request, json 
from IPython.core.display import display, HTML
from itertools import chain
from datetime import date
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
#from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
from selenium import webdriver
from datetime import datetime, date, timedelta
pd.set_option("display.max.columns", None)
pd.set_option("display.max.rows", None)
#driver = webdriver.Chrome("C:/Users/Valentin/Documents/Winamax/chromedriver")
driver = webdriver.Chrome(ChromeDriverManager().install())

def second_largest(numbers):
    count = 0
    m1 = m2 = float('-inf')
    for x in numbers:
        count += 1
        if x > m2:
            if x >= m1:
                m1, m2 = x, m1            
            else:
                m2 = x
    return m2 if count >= 2 else None

def second_lowest(numbers):
    count = 0
    m1 = m2 = float('+inf')
    for x in numbers:
        count += 1
        if x < m2:
            if x <= m1:
                m1, m2 = x, m1            
            else:
                m2 = x
    return m2 if count >= 2 else None

def NPerf(typ ,mini):
    if mini<3:
        return("0")
    else:
        if mini<5:
            return("3")
        else:
            if mini<7:
                return("5")
            else:
                if mini<10:
                    return("7")
                else:
                    if mini<13:
                        return("10")
                    else:
                        if typ == "AST":
                            return("10")
                        if mini<15:
                            return("13")
                        else:
                            return("15")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Get LATEST driver version for 95.0.4638
# Trying to download new driver from https://chromedriver.storage.googleapis.com/95.0.4638.69/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Valentin\.wdm\drivers\chromedriver\win32\95.0.4638.69]

# %% [markdown]
# ![title](img/ESPN.png)

# %%
import pandas as pd
import numpy as np

#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','Tom','Tom','Jack','Jack','Jack','Jack',
   'Lee','Betina','Betina','Betina','Betina']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])
}

#Create a DataFrame
df = pd.DataFrame(d)
df


df.groupby('Name').apply(lambda g: g.assign(
        col1_sum=g.Age.sum(),
        max2=second_largest(g.Rating),
        min2=second_lowest(g.Rating)))
# Out:
#              Name  Age  Rating  col1_sum  max2  min2
# Name
# Betina 8   Betina   40    2.98       167   4.1  3.65
#        9   Betina   30    4.80       167   4.1  3.65
#        10  Betina   51    4.10       167   4.1  3.65
#        11  Betina   46    3.65       167   4.1  3.65
# Jack   3     Jack   23    2.56       105   3.8   3.2
#        4     Jack   30    3.20       105   3.8   3.2
#        5     Jack   29    4.60       105   3.8   3.2
#        6     Jack   23    3.80       105   3.8   3.2
# Lee    7      Lee   34    3.78        34  None  None
# Tom    0      Tom   25    4.23        76  3.98  3.98
#        1      Tom   26    3.24        76  3.98  3.98
#        2      Tom   25    3.98        76  3.98  3.98

# %%
d.groupby(['Player', 'URL', 'Team']).apply(lambda g: g.assign(
        max2_PTS_REB_AST=second_largest(g.PTS_REB_AST),
        min2_PTS_REB_AST=second_lowest(g.PTS_REB_AST))).head()
# Out:
#                                                                                                     Player  \
# Player                 URL                                                Team
# A. BradleyA. BradleyPG https://www.espn.com/nba/player/gamelog/_/id/42... 09_lal 8  A. BradleyA. BradleyPG
#                                                                                  8  A. BradleyA. BradleyPG
#                                                                                  7  A. BradleyA. BradleyPG
#                                                                                  8  A. BradleyA. BradleyPG
#                                                                                  7  A. BradleyA. BradleyPG
#
#                                                                                     Minutes  \
# Player                 URL                                                Team
# ...

# %%
prev = [3,5,99]
datasets = {}
for nb_prev_games in prev:
    ###### Get list of Games
    #soup = BeautifulSoup(driver.page_source)

    #Function Soup
    def get_page(special_match):
        driver.get(special_match)
        try:
            element = driver.find_element_by_class_name('banner-actions-container')
            element.click()
        except:
            do = "Nothing"

    ############ Parameters
    get_page("https://www.espn.com/nba/schedule/_/date/" + date.today().strftime("%Y%m%d"))
    soup = BeautifulSoup(driver.page_source)

    list_Pages = []
    list_Players = []
    for teams in soup.find(class_='schedule has-team-logos align-left').findAll(class_='team-name'):
        p = "https://www.espn.com/nba/team/schedule/_/name/" + teams['href'].replace("/nba/team/_/name/", "").split("/")[0] + "/seasontype/2"
        list_Pages.append(p)
        list_Players.append(p.replace("/schedule/", "/stats/").replace("/seasontype/1", ""))

    #Shorten the list
    #list_Pages = list_Pages[2:4]
    #list_Players = list_Players[2:4]
    #list_Players

    d = pd.DataFrame()
    print("-------- " + str(nb_prev_games) + " Previous games -------")
    print("------------- " + str(int(len(list_Pages)/2)) + " Games" + " ------------")

    for jj in range(len(list_Pages)):
        Page = list_Pages[jj]
        Players = list_Players[jj]
        if(((jj+1)%2)!=0):
            sufx = str(int(jj/2.0+1)) + " "
        else:
            sufx = "  "
        print(sufx + Page.replace("https://www.espn.com/nba/team/schedule/_/name/", "").replace("/seasontype/2", ""))

        ###### Game/Games
        #get_page(special_match)
        get_page(Page)

        ###### Get list of Games
        soup = BeautifulSoup(driver.page_source)
        list_games = []

        for hrefs in soup.find(class_='Table__TBODY').findAll(class_='AnchorLink', href=re.compile("gameId")):
            list_games.append(hrefs['href'].replace("/game/", "/boxscore/"))

        index_games = soup.prettify().split("DATE\n")[1].split("data-idx")
        index_games = int(index_games[len(index_games)-1].split('">\n ')[0].split('="')[1])
        list_games = list_games[0:index_games-1]
        team = str(soup.find(class_='flex flex-wrap').find(class_='db fw-bold')).split('>')[1].split('<')[0]

        # Shorten last n matches
        if ((len(list_games)-nb_prev_games)<0):
            first = 0
        else:
            first = len(list_games)-nb_prev_games
        list_games = list_games[first:len(list_games)]

        get_page(Players)
        soup = BeautifulSoup(driver.page_source)

        list_href_players = []

        for href_players in soup.find(class_='Table__TBODY').findAll(class_='AnchorLink', href=re.compile("player/_/id/")):
            list_href_players.append(href_players['href'].replace("https://www.espn.com/nba/player/_/id/", ""))

        #print(list_href_players)
        list_href_players = [item.replace("karl-anthony-towns", "karl anthony-towns") for item in list_href_players]
        #print(list_href_players)

        def filterOut2(x):return x.split('-')[1]
        list_href_players = list(map(filterOut2, list_href_players))

        for games in list_games:
            get_page(games)
            soup = BeautifulSoup(driver.page_source)

            ############ Creation of the dataset
            try:
                Go = True
                if(team in str(soup.findAll(class_='content desktop')[0].find(class_="table-caption"))):
                    my_table = soup.findAll(class_='content desktop')[0]
                else:
                    my_table = soup.findAll(class_='content desktop')[1]
            except:
                Go = False
                print("Bug ESPN Page")

            if Go:
                my_table = my_table.find(class_='mod-data')
                table_data = []
                for row in my_table.findAll('tr'):
                    row_data = []    
                    URLs = []    

                    for u in row.findAll("a"):
                        URLs.append(u["href"].replace("/player/_/id/","/player/gamelog/_/id/"))

                    for cell in row.findAll('td'):
                        row_data.append(cell.text)

                    row_data = list(chain.from_iterable([row_data, URLs]))

                    if(len(row_data) > 0):
                        if(any(string in row_data[0].replace("'","").lower() for string in list_href_players)):
                            if(row_data[0] == "TEAM" or row_data[0] == "" or len(row_data[0])==1):
                                do = "nothing"
                            else:
                                if('DNP' in row_data[1] or 
                                   row_data[0] == "TEAM"):
                                    do = "nothing"
                                    #data_item = {"Player": row_data[0],
                                    #              "Minutes": 0}
                                else:
                                    if(jj<10):
                                        num = "0" + str(jj)
                                    else:
                                        num = str(jj)

                                    if float(row_data[14])>=20: PT20 = 1
                                    else: PT20 = 0
                                    if float(row_data[14])>=25: PT25 = 1
                                    else: PT25 = 0
                                    if float(row_data[14])>=30: PT30 = 1
                                    else: PT30 = 0

                                    data_item = {"Player": row_data[0],#.Substring(0, input.FirstIndexOf(".")),
                                                  "Minutes": row_data[1],
                                                  "FG": row_data[2],
                                                  "3PT": row_data[3],
                                                  "FT": row_data[4],
                                                  "OREB": row_data[5],
                                                  "DREB": row_data[6],
                                                  "REB": row_data[7],
                                                  "AST": row_data[8],
                                                 #calculated columns
                                                  "PTS_REB_AST": float(row_data[14])+float(row_data[7])+float(row_data[8]),
                                                  "PTS_REB": float(row_data[14])+float(row_data[7]),
                                                  "PTS_AST": float(row_data[14])+float(row_data[8]),
                                                  "REB_AST": float(row_data[7])+float(row_data[8]),
                                                  "20PTS": PT20,
                                                  "25PTS": PT25,
                                                  "30PTS": PT30,
                                                  "STL": row_data[9],
                                                  "BLK": row_data[10],
                                                  "TO": row_data[11],
                                                  "PF": row_data[12],
                                                  "PlusMinus": row_data[13],
                                                  "PTS": row_data[14],
                                                  "Team": num + "_" + Page.replace("https://www.espn.com/nba/team/schedule/_/name/", "").replace("/seasontype/2", ""),
                                                  "team":any(string in row_data[0].lower() for string in list_href_players),
                                                  "URL": row_data[15]
                                    }
                                    table_data.append(data_item)
                data = pd.DataFrame(table_data)#[:-1]
                d = pd.concat([d,data])


    d.dropna(subset = ["REB"], inplace=True)
    d["3PT"] = d["3PT"].astype(str)
    d = d.assign(TPTW = d['3PT'].map(lambda x: x.split('-')[0]))
    d["TPTW"] = d["TPTW"].astype(int, errors = 'raise')
    d["REB"] = d["REB"].astype(int, errors = 'raise')
    d["AST"] = d["AST"].astype(int, errors = 'raise')
    d["PTS"] = d["PTS"].astype(int, errors = 'raise')
    d["PTS_REB_AST"] = d["PTS_REB_AST"].astype(int, errors = 'raise')
    d["PTS_REB"] = d["PTS_REB"].astype(int, errors = 'raise')
    d["PTS_AST"] = d["PTS_AST"].astype(int, errors = 'raise')
    d["Minutes"] = d["Minutes"].astype(int, errors = 'raise')

    player_team = d[['Player', 'URL', 'Team']]
    df = d.groupby(['Player', 'URL', 'Team']).describe(percentiles=[.5])
    #df = df[df['REB']['count']>=2]
    a = df["Minutes"].sort_values(by = "mean", ascending = False, axis=0).index
    df = df.reindex(a)
    df.reset_index(level=1, inplace=True)
    print("----------------------------------")

    df[list(df.filter(regex='mean'))] = round(df[list(df.filter(regex='mean'))],2)
    df["NbGames"]=df["Minutes"]["count"]
    df["ScoreJ"]=df["PTS_REB_AST"]["mean"]
    #df = df.sort_values('ScoreJ', ascending=False)
    df = df[df.columns.drop(list(df.filter(regex='count')))]
    df = df[df.columns.drop(list(df.filter(regex='std')))]
    df = df[df.columns.drop(list(df.filter(regex='50%')))]
    #df = df[df.columns.drop(list(df.filter(regex='mean')))]
    df = df[['URL', 'NbGames', 'PTS_REB_AST', 'PTS_REB', 'PTS_AST', 'REB_AST', 'PTS', 'REB', 'AST', 'TPTW', 'Minutes', '20PTS', '25PTS', '30PTS', 'ScoreJ']]

    def make_clickable(val):
        if (isinstance(val, str) and val.find("http") != -1):
            return '<a href="{}">{}</a>'.format(val,val.split("id/")[1].split("/")[1])
        else:
            return val

    cm = sns.light_palette("green", as_cmap=True)
    bl = sns.light_palette("blue", as_cmap=True)
    rd = sns.light_palette("red", as_cmap=True)
    pr = sns.light_palette("purple", as_cmap=True)
    rg = sns.light_palette("orange", as_cmap=True)
    df = df.sort_values(by=["Team", "ScoreJ"], ascending=[True,False])
    #df = df[df['ScoreJ']>=6]

    df["FullName"] = df["URL"].apply(lambda p: p.split("/")[len(p.split("/"))-1].replace("-", "").replace("'", "").replace(".", "").replace(" ", "").lower())
    df.reset_index(level=0, inplace=True)
    df.reset_index(level=0, inplace=True)
    df = df.drop(['ScoreJ', 'Player'], 1)
    datasets[nb_prev_games] = df
print(prev)
# Out:
# -------- 3 Previous games -------
# ------------- 7 Games ------------
# 1 sa
#   lal
# 2 mil
#   atl
# 3 gs
#   cha
# 4 phx
#   hou
# 5 bkn
#   okc
# 6 por
#   den
# 7 chi
#   lac
# ----------------------------------
# C:\Users\Valentin\anaconda3\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# -------- 5 Previous games -------
# ------------- 7 Games ------------
# 1 sa
#   lal
# 2 mil
#   atl
# 3 gs
#   cha
# 4 phx
#   hou
# 5 bkn
#   okc
# 6 por
#   den
# 7 chi
#   lac
# ----------------------------------
# C:\Users\Valentin\anaconda3\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# -------- 99 Previous games -------
# ...

# %% [markdown]
# ![title](img/UNIBET.png)

# %%
CoteMatch = "https://www.unibet.fr/zones/v3/sportnode/markets.json?nodeId=627957624&filter=R%25C3%25A9sultat&marketname=Vainqueur%2520du%2520match%2520(prolong.%2520incluses)"
with urllib.request.urlopen(CoteMatch) as url:
    json_data = json.loads(url.read().decode())
row_data = []  
for d in json_data['marketsByType'][0]['days']:
    for e in d['events']:
        match = e['eventName']                
        for j in e['markets'][0]['selections']:
            if(j['name'].find("Moins") == -1):
                data_item = {"Match": match,
                             "Team": j['name'],
                              "OddWin":round(1+float(j['currentPriceUp'])/float(j['currentPriceDown']),2)                         
                            }
                row_data.append(data_item)
df3 = pd.DataFrame(row_data)

df3["Date"] = date.today().strftime("%d/%m/%Y")
df3["id"] = df3["Date"] + df3["Match"]
df3 = df3.sort_values(['id'])
df3 = df3[df3.columns.tolist()[-1:] + df3.columns.tolist()[:-1]]

#Save odds as CSV
csv = pd.read_csv("Odds_Match.csv")
def bool(p):
    #if p in pd.read_csv("Odds_NBA.csv")["id"]:
    if any(csv['id'].str.contains(str(p))):
        return(False)
    else:
        return(True)

b = df3.apply(lambda p : bool(p["id"]), axis=1)
csv = pd.concat([csv,df3[b]])
csv.to_csv('Odds_Match.csv', index=False, encoding='utf-8')

# %%
URL_prefix = "https://www.unibet.fr/zones/v3/sportnode/markets.json?nodeId=627956958&filter="

Spe_Joueurs = ["Sp%25C3%25A9cial%2520joueurs&marketname=Performance%2520du%2520Joueur%2520(Points%2520%252B%2520Rebonds%2520%252B%2520Passes)",  #Pts+Reb+Ast
               "Sp%25C3%25A9cial%2520joueurs&marketname=Performance%2520du%2520Joueur%2520(Points%2520%252B%2520Rebonds)", #Pts+Reb
               "Sp%25C3%25A9cial%2520joueurs&marketname=Performance%2520du%2520Joueur%2520(Points%2520%252B%2520Passes)",  #Pts+Ast
               "Sp%25C3%25A9cial%2520joueurs&marketname=Performance%2520du%2520Joueur%2520(Passes%2520%252B%2520Rebonds)", #Reb+Ast
               "Sp%25C3%25A9cial%2520joueurs&marketname=Nombre%2520de%2520rebonds%2520du%2520joueur", #Reb
               "Sp%25C3%25A9cial%2520joueurs&marketname=Nombre%2520de%2520passes%2520du%2520joueur", #Ast
               "Scoreurs&marketname=Joueur%2520marquant%252020%2520points%2520ou%2520plus", #20PTS
               "Scoreurs&marketname=Joueur%2520marquant%252025%2520points%2520ou%2520plus", #25PTS
               "Scoreurs&marketname=Joueur%2520marquant%252030%2520points%2520ou%2520plus", #30PTS
               "Scoreurs&marketname=Joueur%2520marquant%252035%2520points%2520ou%2520plus", #35PTS
               "Scoreurs&marketname=Joueur%2520marquant%252040%2520points%2520ou%2520plus",  #40PTS
               "Sp%25C3%25A9cial%2520joueurs&marketname=Joueur%2520prenant%25203%2520rebonds%2520ou%2520plus",  #3REB+
               "Sp%25C3%25A9cial%2520joueurs&marketname=Joueur%2520prenant%25205%2520rebonds%2520ou%2520plus",  #5REB+
               "Sp%25C3%25A9cial%2520joueurs&marketname=Joueur%2520prenant%25207%2520rebonds%2520ou%2520plus",  #7REB+
               "Sp%25C3%25A9cial%2520joueurs&marketname=Joueur%2520prenant%252010%2520rebonds%2520ou%2520plus",  #10REB+
               "Sp%25C3%25A9cial%2520joueurs&marketname=Joueur%2520prenant%252013%2520rebonds%2520ou%2520plus",  #13REB+
               "Sp%25C3%25A9cial%2520joueurs&marketname=Joueur%2520prenant%252015%2520rebonds%2520ou%2520plus",  #15REB+
               "Sp%25C3%25A9cial%2520joueurs&marketname=Joueur%2520r%25C3%25A9alisant%25203%2520passes%2520ou%2520plus",  #3AST+
               "Sp%25C3%25A9cial%2520joueurs&marketname=Joueur%2520r%25C3%25A9alisant%25205%2520passes%2520ou%2520plus",  #5AST+
               "Sp%25C3%25A9cial%2520joueurs&marketname=Joueur%2520r%25C3%25A9alisant%25207%2520passes%2520ou%2520plus",  #7AST+
               "Sp%25C3%25A9cial%2520joueurs&marketname=Joueur%2520r%25C3%25A9alisant%252010%2520passes%2520ou%2520plus",  #10AST+
              ]
Spe_Joueurs_indx = ["PTS_REB_AST", "PTS_REB"
                    , "PTS_AST", "REB_AST", "REB", "AST", "20PTS", "25PTS", "30PTS", "35PTS", "40PTS"
                    ,"3REB+","5REB+","7REB+","10REB+","13REB+","15REB+","3AST+","5AST+","7AST+","10AST+"
                   ]



print("------------- " + str(int(len(list_Pages)/2)) + " games" + " ------------")
print("------------ Odds for ------------")
df2 = pd.DataFrame()
i_match = 1

for b in range(len(Spe_Joueurs_indx)):
    u = URL_prefix+Spe_Joueurs[b]
    with urllib.request.urlopen(u) as url:
        json_data = json.loads(url.read().decode())
        
    row_data = []  
    if json_data['singleSportId'] != None:
        for d in json_data['marketsByType'][0]['days']:
            for e in d['events']:
                match = e['eventName']
                nb = 0
                for j in e['markets'][0]['selections']:
                    if(j['name'].find("Moins") == -1):
                        nb = nb+1
                        if(b == 0 and j == e['markets'][0]['selections'][len(e['markets'][0]['selections'])-1]): 
                            print(str(i_match) + " " + match + " (" + str(nb) + " players)")
                            i_match = i_match + 1
                        if(b<6): #from 20PTS
                            data_item = {"Match": match,
                                        "Player": j['name'].split(" - ")[0],
                                         Spe_Joueurs_indx[b]:[int(s) for s in j['name'].split(" - ")[1].replace(".","").replace(",","").split() if s.isdigit()][0]/10,
                                         "Odd"+Spe_Joueurs_indx[b]:round(1+float(j['currentPriceUp'])/float(j['currentPriceDown']),2)
                                        }
                        else:
                            if(b<11):
                                data_item = {"Match": match,
                                             "Player": j['name'],
                                             "Odd"+Spe_Joueurs_indx[b]:round(1+float(j['currentPriceUp'])/float(j['currentPriceDown']),2)                         
                                            }
                            else:
                                data_item = {"Match": match,
                                            "Player": j['name'].split(" - ")[0],
                                             "Odd"+Spe_Joueurs_indx[b]:round(1+float(j['currentPriceUp'])/float(j['currentPriceDown']),2)
                                            }
                        row_data.append(data_item)
        data = pd.DataFrame(row_data)
        if b == 0:
            df2 = data
        else:
            df2 = df2.merge(data, on=['Match','Player'], how='outer')
df2["name"] = df2["Player"].apply(lambda p: p.replace("-", "").replace("'", "").replace(".", "").lower())
df2["id"] = date.today().strftime("%d/%m/%Y") + df2["name"] 

#Errors one the names
df2["FullName"] = df2["name"]#.apply(lambda p: p.replace(" ", ""))
df2["FullName"] = df2["FullName"].apply(lambda p: "maurice harkless" if p == "moe harkless" else p)
df2["FullName"] = df2["FullName"].apply(lambda p: "robertwilliamsiii" if p == "robert williams" else p)
df2["name"] = df2["FullName"]

name = df2["name"]
df2 = df2.drop("name", axis=1)

#Save odds as CSV
csv = pd.read_csv("Odds_NBA.csv")
def bool(p):
    if any(csv['id'].str.contains(str(p))):
        return(False)
    else:
        return(True)

b = df2.apply(lambda p : bool(p["id"]), axis=1)
csv = pd.concat([csv,df2[b]]).sort_values(["FullName", 'id'])

csv.to_csv('Odds_NBA.csv', index=False, encoding='utf-8')
#Remove date
#csv = pd.read_csv("Odds_NBA.csv")
#csv = csv[csv["id"].apply(lambda p : "04/11/2021" not in p)]
#csv.to_csv('Odds_NBA.csv', index=False, encoding='utf-8')
df2["FullName"] = name.apply(lambda p: p.replace(" ", ""))
# Out:
# ------------- 7 games ------------
# ------------ Odds for ------------
# 1 Los Angeles Lakers - San Antonio Spurs (7 players)
# 2 Charlotte Hornets - Golden State Warriors (10 players)
# 3 Houston Rockets - Phoenix Suns (9 players)
# 4 Oklahoma City Thunder - Brooklyn Nets (9 players)

# %%
df = datasets[5]
#df = datasets[3]
#df = datasets[5]
#df = datasets[99]
#df.style.format(make_clickable).background_gradient(cmap=rd, subset=['TPTW']).background_gradient(cmap=bl, subset=['PTS_REB_AST', 'PTS_REB', 'PTS_AST']).background_gradient(cmap=cm, subset=['PTS', 'REB', 'AST']).background_gradient(cmap=pr, subset=['Minutes']).background_gradient(cmap=rg, subset=['Minutes']).set_precision(0)

# %%
final = df2.merge(df, on=["FullName"], how='left')
final.head()

def Perf(Min, Max, Bet):
    if float(Min) > float(Bet):
        return((float(Min) - float(Bet))/float(Bet))
    else:
        if float(Max) < float(Bet):
            return(float(Max) - float(Bet)/float(Bet))
        else:
            return(0)
        
def Perf_mean(Mean, Bet):
    return(round(float(Mean) - float(Bet),2))
        
final["res_PTS_REB_AST"] = final.apply(lambda p : Perf(p["PTS_REB_AST","min"], p["PTS_REB_AST","max"], p["PTS_REB_AST"]), axis=1)
final["res_PTS_REB"] = final.apply(lambda p : Perf(p["PTS_REB","min"], p["PTS_REB","max"], p["PTS_REB"]), axis=1)
final["res_PTS_AST"] = final.apply(lambda p : Perf(p["PTS_AST","min"], p["PTS_AST","max"], p["PTS_AST"]), axis=1)
final["res_REB_AST"] = final.apply(lambda p : Perf(p["REB_AST","min"], p["REB_AST","max"], p["REB_AST"]), axis=1)
final["res_REB"] = final.apply(lambda p : Perf(p["REB","min"], p["REB","max"], p["REB"]), axis=1)
final["res_AST"] = final.apply(lambda p : Perf(p["AST","min"], p["AST","max"], p["AST"]), axis=1)

final["mean_PTS_REB_AST"] = final.apply(lambda p : Perf_mean(p["PTS_REB_AST","mean"], p["PTS_REB_AST"]), axis=1)
#final["mean_PTS_REB_AST"] = final.apply(lambda p : 0 if p["res_PTS_REB_AST"]==0 else p["mean_PTS_REB_AST"], axis=1)
final["mean_PTS_REB"] = final.apply(lambda p : Perf_mean(p["PTS_REB","mean"], p["PTS_REB"]), axis=1)
#final["mean_PTS_REB"] = final.apply(lambda p : 0 if p["res_PTS_REB"]==0 else p["mean_PTS_REB"], axis=1)
final["mean_PTS_AST"] = final.apply(lambda p : Perf_mean(p["PTS_AST","mean"], p["PTS_AST"]), axis=1)
#final["mean_PTS_AST"] = final.apply(lambda p : 0 if p["res_PTS_AST"]==0 else p["mean_PTS_AST"], axis=1)

final["mean_REB_AST"] = final.apply(lambda p : Perf_mean(p["REB_AST","mean"], p["REB_AST"]), axis=1)
#final["mean_REB_AST"] = final.apply(lambda p : 0 if p["res_REB_AST"]==0 else p["mean_REB_AST"], axis=1)
final["mean_REB"] = final.apply(lambda p : Perf_mean(p["REB","mean"], p["REB"]), axis=1)
#final["mean_REB"] = final.apply(lambda p : 0 if p["res_REB"]==0 else p["mean_REB"], axis=1)
final["mean_AST"] = final.apply(lambda p : Perf_mean(p["AST","mean"], p["AST"]), axis=1)
#final["mean_AST"] = final.apply(lambda p : 0 if p["res_AST"]==0 else p["mean_AST"], axis=1)


final["res_20PTS"] = final.apply(lambda p : 0 if (p["Odd20PTS"] * p["20PTS","mean"])<=1 else p["Odd20PTS"] * p["20PTS","mean"], axis=1)
final["res_25PTS"] = final.apply(lambda p : 0 if (p["Odd25PTS"] * p["25PTS","mean"])<=1 else p["Odd25PTS"] * p["25PTS","mean"], axis=1)
final["res_30PTS"] = final.apply(lambda p : 0 if (p["Odd30PTS"] * p["30PTS","mean"])<=1 else p["Odd30PTS"] * p["30PTS","mean"], axis=1)

final["nREB"] = final.apply(lambda p : 0 if (p["Odd30PTS"] * p["30PTS","mean"])<=1 else p["Odd30PTS"] * p["30PTS","mean"], axis=1)

final["res"] = abs(final["res_PTS_REB_AST"]) + abs(final["res_PTS_REB"]) + abs(final["res_PTS_AST"]) + abs(final["res_REB_AST"]) + abs(final["res_REB"]) + abs(final["res_AST"]) #Max
final["res_PTS"] = final["res_20PTS"]+final["res_25PTS"]+final["res_30PTS"]
final["URL"] = final["URL",""]

final = final.sort_values('res', ascending=False)
final["NbGames"] = final["NbGames",""]
final = final[(final['res']>=0.5) | (final['res']<=-0.5) #| (final['res_PTS']>0)
             ]

final[["PTS_REB_AST", 'URL', 'NbGames', 'res_PTS_REB_AST', 'res_PTS_REB', 'res_PTS_AST', 'res_REB_AST', 'res_REB', 'res_AST', 'mean_PTS_REB_AST', 'mean_PTS_REB', 'mean_PTS_AST', 'mean_REB_AST', 'mean_REB', 'mean_AST'
       #,'res_20PTS', 'res_25PTS', 'res_30PTS'
      ]].style.format(make_clickable).background_gradient(cmap=cm, subset=['res_PTS_REB_AST', 'res_PTS_REB', 'res_PTS_AST', 'res_REB_AST', 'res_REB', 'res_AST'
                                                                          ]).background_gradient(cmap=bl, subset=['mean_PTS_REB_AST', 'mean_PTS_REB', 'mean_PTS_AST', 'mean_REB_AST', 'mean_REB', 'mean_AST'
                                                                                                                 ]).set_precision(0)
# Out:
# C:\Users\Valentin\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:648: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)
# C:\Users\Valentin\anaconda3\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# <style  type="text/css" >
# #T_a7b03_row0_col3,#T_a7b03_row0_col5,#T_a7b03_row1_col3,#T_a7b03_row1_col4,#T_a7b03_row1_col5,#T_a7b03_row1_col6,#T_a7b03_row1_col7,#T_a7b03_row2_col3,#T_a7b03_row2_col4,#T_a7b03_row3_col3,#T_a7b03_row3_col4,#T_a7b03_row3_col5,#T_a7b03_row3_col8,#T_a7b03_row4_col3,#T_a7b03_row4_col4,#T_a7b03_row4_col5,#T_a7b03_row4_col7,#T_a7b03_row5_col3,#T_a7b03_row5_col4,#T_a7b03_row5_col5,#T_a7b03_row5_col7,#T_a7b03_row6_col3,#T_a7b03_row6_col5{
#             background-color:  #ebf3eb;
# ...

# %%
df_REB_ASS = datasets[5]
                        
final = df2.merge(df_REB_ASS, on=["FullName"], how='left')
final["cREB"] = final.apply(lambda p : 0 if (NPerf("REB", p["REB","min"])=="0") else p["Odd" + str(NPerf("REB", p["REB","min"])) + "REB+"], axis=1)
final["REB"] = final.apply(lambda p : NPerf("REB", p["REB","min"]), axis=1)
final["cAST"] = final.apply(lambda p : 0 if (NPerf("AST", p["AST","min"])=="0") else p["Odd" + str(NPerf("AST", p["AST","min"])) + "AST+"], axis=1)
final["AST"] = final.apply(lambda p : NPerf("AST", p["AST","min"]), axis=1)
final["res"] = final["cREB"]+final["cAST"]

final = final[(final['res']>=1)
             ]
final["mean_REB"] = final.apply(lambda p : 0 if(p["REB"]=="0") else round(float(p["REB","mean"]) - float(p["REB"]),2), axis=1)
final["mean_AST"] = final.apply(lambda p : 0 if(p["AST"]=="0") else round(float(p["AST","mean"]) - float(p["AST"]),2), axis=1)
final["URL"] = final["URL",""]
final = final.sort_values(["cREB", "cAST"], ascending=False)
final["NbGames"] = final["NbGames",""]
final = final[(final['res']>=1.1)
             ]

final[['URL', 'NbGames', 'REB', 'cREB', 'mean_REB', 'AST', 'cAST', 'mean_AST'
       #,'res_20PTS', 'res_25PTS', 'res_30PTS'
      ]].style.format(make_clickable).background_gradient(cmap=cm, subset=['cREB', 'cAST'
                                                                          ]).background_gradient(cmap=bl, subset=['mean_REB', 'mean_AST'
                                                                                                                 ]).set_precision(0)
# Out:
# C:\Users\Valentin\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:648: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)
# C:\Users\Valentin\anaconda3\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# <style  type="text/css" >
# #T_e42ac_row0_col3,#T_e42ac_row1_col3,#T_e42ac_row15_col6{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_e42ac_row0_col4,#T_e42ac_row1_col4,#T_e42ac_row2_col4,#T_e42ac_row4_col4,#T_e42ac_row13_col4{
#             background-color:  #a2a2f7;
#             color:  #000000;
#         }#T_e42ac_row0_col6{
#             background-color:  #128912;
#             color:  #f1f1f1;
#         }#T_e42ac_row0_col7{
# ...
